# %%
#importing required packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Adding Dataset to a data frame
df = pd.read_csv('D:\Codes\Python\Python-projects\World GDP Data Analysis\Dataset\gapminder_data_graphs.csv')

# %%
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
df.head()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0  Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1  Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2  Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3  Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4  Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
#
#    services
# 0      24.4
# 1      24.6
# 2      24.7
# 3      24.7
# 4      25.6

# %%
df.tail()
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2

# %%
df.shape
# Out:
# (3675, 8)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country         object
# continent       object
# year             int64
# life_exp       float64
# hdi_index      float64
# co2_consump    float64
# gdp            float64
# services       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   object
#  1   continent    3675 non-null   object
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 229.8+ KB

# %%
null_rows=df[df.isnull().any(axis=1)]

# %%
null_rows
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 63         Angola    Africa  1998      50.6        NaN       0.4740  2490.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3572      Vanuatu   Oceania  2000      63.6        NaN       0.4560  2840.0
# 3573      Vanuatu   Oceania  2001      63.6        NaN       0.4650  2680.0
# 3574      Vanuatu   Oceania  2002      63.6        NaN       0.4350  2480.0
# 3575      Vanuatu   Oceania  2003      63.7        NaN       0.4240  2520.0
# 3576      Vanuatu   Oceania  2004      63.7        NaN       0.2870  2550.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
country= df['country']

# %%
print(country.head())
print(country.tail())
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object
# 3670    Zimbabwe
# 3671    Zimbabwe
# 3672    Zimbabwe
# 3673    Zimbabwe
# 3674    Zimbabwe
# Name: country, dtype: object

# %%
subset_list= ['country','continent','year','gdp']
df_subset= df[subset_list]
df_subset.head()
# Out:
#        country continent  year    gdp
# 0  Afghanistan      Asia  1998    NaN
# 1  Afghanistan      Asia  1999    NaN
# 2  Afghanistan      Asia  2000    NaN
# 3  Afghanistan      Asia  2001    NaN
# 4  Afghanistan      Asia  2002  333.0

# %%
df.loc[500]
# Out:
# country        Bulgaria
# continent        Europe
# year               2015
# life_exp           73.2
# hdi_index         0.809
# co2_consump        6.69
# gdp              7060.0
# services           63.2
# Name: 500, dtype: object

# %%
flag=True

while(flag):
    n=int(input("Enter the row number you want to check "))
    
    if(n>0):
        print(df.loc[n-1])
        flag=False
    else:
        pass
# Out:
# Enter the row number you want to check 4
# country        Afghanistan
# continent             Asia
# year                  2001
# life_exp              54.8
# hdi_index            0.353
# co2_consump         0.0376
# gdp                    NaN
# services              24.7
# Name: 3, dtype: object

# %%
df.loc[[0,99,199]]
# Out:
#          country      continent  year  life_exp  hdi_index  co2_consump  \
# 0    Afghanistan           Asia  1998      53.3      0.344       0.0522
# 99     Argentina  South America  2013      76.3      0.835       4.5600
# 199      Bahamas  North America  2008      73.5      0.804       6.8700
#
#          gdp  services
# 0        NaN      24.4
# 99   14100.0      75.4
# 199  34300.0      80.9

# %%
df.iloc[[1,-1,0]]
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
#
#       services
# 1         24.6
# 3674      27.2
# 0         24.4

# %%
print(df.loc[1,'country'])
# Out:
# Afghanistan

# %%
mean_lifeExp= df.groupby('country')['life_exp'].mean()
print(mean_lifeExp)
# Out:
# country
# Afghanistan    58.857143
# Albania        77.080952
# Algeria        73.571429
# Angola         58.438095
# Argentina      75.404762
#                  ...
# Vanuatu        64.219048
# Vietnam        73.071429
# Yemen          66.171429
# Zambia         53.366667
# Zimbabwe       51.895238
# Name: life_exp, Length: 175, dtype: float64

# %%
print(df.groupby('year')['life_exp'].mean())
# Out:
# year
# 1998    66.912000
# 1999    67.125714
# 2000    67.410286
# 2001    67.676000
# 2002    67.873714
# 2003    68.094286
# 2004    68.371429
# 2005    68.735429
# 2006    69.122857
# 2007    69.516571
# 2008    69.850286
# 2009    70.217714
# 2010    70.473143
# 2011    70.967429
# 2012    71.312571
# 2013    71.607429
# 2014    71.804000
# 2015    72.045143
# 2016    72.324000
# 2017    72.584571
# 2018    72.810857
# Name: life_exp, dtype: float64

# %%
print(df.groupby('year')['life_exp'].median())
# Out:
# year
# 1998    69.9
# 1999    70.2
# 2000    70.3
# 2001    70.6
# 2002    70.7
# 2003    70.9
# 2004    71.0
# 2005    71.1
# 2006    71.2
# 2007    71.6
# 2008    71.7
# 2009    72.1
# 2010    72.3
# 2011    72.8
# 2012    73.0
# 2013    72.9
# 2014    73.1
# 2015    73.3
# 2016    73.7
# 2017    73.8
# 2018    73.9
# Name: life_exp, dtype: float64

# %%
op=df.groupby(['year','country'])[['life_exp','gdp']].mean()

# %%
op.tail()
# Out:
#                life_exp     gdp
# year country
# 2018 Vanuatu       65.3  2860.0
#      Vietnam       74.3  2460.0
#      Yemen         66.1  1290.0
#      Zambia        62.5  1370.0
#      Zimbabwe      60.6  1510.0

# %%
print(df.groupby('year')['gdp'].nunique())
# Out:
# year
# 1998    158
# 1999    156
# 2000    160
# 2001    165
# 2002    165
# 2003    167
# 2004    160
# 2005    162
# 2006    170
# 2007    163
# 2008    167
# 2009    167
# 2010    162
# 2011    163
# 2012    165
# 2013    161
# 2014    162
# 2015    165
# 2016    165
# 2017    163
# 2018    164
# Name: gdp, dtype: int64

# %%
globalLifeExpectancy=df.groupby('year')['life_exp'].mean()

# %%
globalLifeExpectancy.plot()
# Out:
# <AxesSubplot:xlabel='year'>
